# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshrock7897/Data-Analysis/blob/main/Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# # 🔹 **1. Introduction to Plotly**
#
# ## 📊 **Overview of Plotly**
# - 📌 Plotly is an **open-source graphing library** for Python.
# - 🌐 It helps you create **interactive, web-based, publication-quality** visualizations.
# - 🧰 Supports a wide variety of **chart types** like line plots, bar charts, scatter plots, maps, 3D plots, and more.
# - 📈 Widely used for **data analysis**, dashboards, and storytelling with data.
# - 🔄 Integrates well with **Pandas**, **Jupyter Notebooks**, **Dash**, and other libraries.
#
# ## ⚙️ **Installation and Setup**
# To install Plotly in your Python environment:
#
# ```bash
# pip install plotly
# ```
#
# ✅ Once installed, you're ready to start plotting!
#
# > 📝 *Tip: Use `pip install plotly --upgrade` to ensure you're using the latest version.*
#
# ---

# %% [markdown]
# ---
#
# ## 🌐 **Online vs. Offline Mode in Plotly**
#
# > 📝 **Note:** Plotly can be used in **both online and offline** modes.
#
# ### 🟢 **Offline Mode**
# - 🖥️ Useful when you want to create and view charts **without internet** access.
# - 📦 Requires importing from the `plotly.offline` module.
# - 🔧 Common imports for offline use:
#
# ```python
# from plotly.offline import plot, iplot, init_notebook_mode
# init_notebook_mode(connected=True)
# ```
#
# - 📂 Generates HTML files or embeds plots inside Jupyter Notebooks.
#
# ### 🌐 **Online Mode**
# - Requires a **Plotly account** and **internet connection**.
# - Charts are stored in your online Plotly account.
# - Collaboration-friendly and great for sharing visualizations.
#
# ---

# %% [markdown]
# ---
#
# ## ⚔️ **Comparison: Matplotlib vs. Seaborn vs. Plotly for Line Plots**
#
# ---
#
# ### 📘 **Matplotlib**
#
# - 🧾 **Overview**:
#   A **foundational plotting library** in Python. Known for being **low-level**, giving you complete control over every element in a plot.
#
# - ✅ **Pros**:
#   - 🎛️ **Highly customizable** — build almost any kind of plot.
#   - 📚 **Rich ecosystem** — integrates well with NumPy, Pandas, etc.
#   - 👥 **Large user community** and extensive documentation.
#
# - ❌ **Cons**:
#   - 🧱 More **code-heavy** for complex visualizations.
#   - 🚫 **Limited interactivity** — mainly static plots.
#   - 🎨 Less modern aesthetic by default (can be improved with styles).
#
# ---

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Matplotlib Line Plot')
plt.show()

# %% [markdown]
# ---
#
# ### 🎨 **Seaborn**
#
# - 🧾 **Overview**:
#   A **high-level interface** built on top of Matplotlib, designed to make **statistical graphics** easier and more beautiful. Works seamlessly with **Pandas DataFrames**.
#
# - ✅ **Pros**:
#   - ✨ **Beautiful default styles** for professional-looking plots.
#   - 📊 Simplifies **complex statistical visualizations** (e.g., violin plots, heatmaps).
#   - 🔗 **Tightly integrated** with Pandas — easy to use with real-world datasets.
#
# - ❌ **Cons**:
#   - 🛠️ **Less flexible** than Matplotlib for highly customized plots.
#   - 🚫 **Limited interactivity** — outputs are still mostly static.
#
# ---

# %%
import seaborn as sns
import pandas as pd

data = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 15, 13, 17]})
sns.lineplot(x='x', y='y', data=data)
plt.title('Seaborn Line Plot')
plt.show()

# %% [markdown]
# ---
#
# ### 🚀 **Plotly**
#
# - 🧾 **Overview**:
#   A powerful **graphing library** for creating **interactive, web-based visualizations**. Ideal for dashboards, analytics apps, and **data storytelling**. Works offline or online.
#
# - ✅ **Pros**:
#   - 🖱️ **Interactive plots** (zoom, hover, pan, tooltips).
#   - 📊 **Wide variety of chart types**, including animations and subplots.
#   - 🌍 Built-in support for **3D plots** and **geographic maps**.
#   - 💡 Easy sharing via **HTML export**, notebooks, or web platforms.
#
# - ❌ **Cons**:
#   - 🧗‍♂️ Can have a **steeper learning curve** if you're used to static libraries.
#   - 💰 The **free tier** has limitations for advanced features (e.g., cloud collaboration).
#
# ---

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=[1, 2, 3, 4], y=[10, 15, 13, 17], mode='lines'))
fig.update_layout(title='Plotly Line Plot', xaxis_title='X-axis', yaxis_title='Y-axis')
fig.show()

# %% [markdown]
# ---
#
# ### 🧠 **Remember This!**
#
# - 🎯 **Matplotlib** → Best for **highly customized, static plots**. Great when you need full control over every detail.
#
# - 🎨 **Seaborn** → Ideal for **quick and beautiful statistical plots** with minimal code. Great for EDA and reports.
#
# - 🌐 **Plotly** → Perfect for **interactive, web-based plots** that are easy to **share, explore, and customize**.
#
# ---

# %% [markdown]
# ---
#
# # 🔢 **2. Plotly: Basic Charts**
#
# ## 2️⃣.1️⃣ **Scatter Plots**
#
# - 🔍 **Definition**:
#   Scatter plots are used to **visualize the relationship** between **two continuous variables**.
#   In Plotly, this is done using `go.Scatter()` from the `plotly.graph_objs` module.
#
# ---
#
# ### ⚙️ **Key Parameters of `go.Scatter()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📌 `x`           | Array of **x-coordinates**.                                                 |
# | 📌 `y`           | Array of **y-coordinates**.                                                 |
# | 🎯 `mode`        | Plot mode: `'markers'`, `'lines'`, or `'lines+markers'`.                    |
# | 🏷️ `name`        | **Name of the trace**, shown in the legend.                                |
# | 🎨 `marker`      | Dictionary to **customize markers** (e.g., `size`, `color`).                |
# | 🗨️ `text` / `hovertext` | Adds **hover annotations** or labels to data points.               |
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 17, 10]

# Create a trace
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', name='scatter'))

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 2️⃣.2️⃣ **Line Plots**
#
# - 📈 **Definition**:
#   Line plots are used to **show trends or changes over time** by connecting data points with straight lines.
#   In Plotly, line plots are created using `go.Scatter()` with `mode='lines'`.
#
# ---
#
# ### ⚙️ **Key Parameters of Line Plots**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📌 `x`           | Array of **x-values** (e.g., time, sequence).                               |
# | 📌 `y`           | Array of **y-values**.                                                      |
# | 🧭 `mode`        | Set to `'lines'` to connect points with lines.                              |
# | 🏷️ `name`        | **Legend label** for the line.                                              |
# | 🎨 `marker`      | Optional: still used for styling points, if `lines+markers` is selected.    |
# | 🗨️ `text` / `hovertext` | Adds annotations or info when hovering.                            |
#
# > ✅ **Note**: Everything from Scatter Plots applies here — the only difference is setting `mode='lines'`.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 17, 10]

# Create a trace
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines', name='line'))

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 2️⃣.3️⃣ **Bar Charts**
#
# - 📈 **Definition**:
#   Bar charts display **categorical data** with **rectangular bars**.
#   In Plotly, use `go.Bar()` for **vertical** or **horizontal** bar charts.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Bar()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Categories or numbers (for **vertical bars**).                              |
# | 📏 `y`           | Values (for **vertical bars**).                                             |
# | 🔃 `orientation` | `'v'` for vertical (default), `'h'` for horizontal bars.                    |
# | 🏷️ `name`       | Trace name for the **legend**.                                              |
# | 💬 `text` / `hovertext` | Add annotations or labels on bars or on **hover**.                  |
#
# > ✅ **Tip**: For horizontal bars, use `x` for values, `y` for categories, and set `orientation='h'`.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [5, 10, 15, 20]

# Create a trace
trace = go.Bar(
    x=categories,  # X-axis represents categories
    y=values,      # Y-axis represents values
    orientation='v', # Vertical bars (default)
    name='bar'      # Name for the legend
)

# Create a figure and add the trace
fig = go.Figure(data=[trace])

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 2️⃣.4️⃣ **Histograms**
#
# - 📊 **Definition**:
#   Histograms show the **distribution** of a dataset by grouping data into bins.
#   In Plotly, use `go.Histogram()` to create histograms.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Histogram()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of data to be **binned**.                                            |
# | 📏 `nbinsx`      | Number of bins for the histogram.                                          |
# | 🛑 `bargap`      | Gap between bars.                                                          |
# | 🎨 `marker`      | Customize bar appearance (e.g., color, line).                              |
#
# > ✅ **Tip**: Adjust `nbinsx` to control the granularity of the distribution.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a histogram trace
fig = go.Figure(data=[go.Histogram(x=data, nbinsx=5, marker_color='red')])

# Customize the layout
fig.update_layout(
    title_text='Histogram',
    xaxis_title='Value',
    yaxis_title='Frequency'
)

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 2️⃣.5️⃣ **Box Plots**
#
# - 📊 **Definition**:
#   Box plots visualize the **distribution** of data using a five-number summary: **minimum**, **first quartile**, **median**, **third quartile**, and **maximum**.
#   In Plotly, use `go.Box()` to create box plots.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Box()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `y`           | Array of data for the **box plot**.                                        |
# | 🏷️ `name`       | Trace name for the **legend**.                                             |
# | 🔍 `boxpoints`   | Display individual points: `'outliers'`, `'suspectedoutliers'`, `'all'`, or `False`. |
# | 🎨 `jitter`, `whiskerwidth` | Customize appearance (point scatter and whisker width).             |
#
# > ✅ **Tip**: Use `boxpoints='all'` to show all data points alongside the box plot.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a trace (correct 'y' for box plot data)
trace = go.Box(
    y=data,  # Box plot uses data on the y-axis
    name='box'
)

# Create a figure and plot it
fig = go.Figure(data=[trace])

# Show the plot (use fig.show() instead of pyo.plot)
fig.show()

# %% [markdown]
# ---
#
# ## 2️⃣.6️⃣ **Pie Charts**
#
# - 📊 **Definition**:
#   Pie charts display **proportions** of a whole as **slices** of a circle.
#   In Plotly, use `go.Pie()` to create pie charts.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Pie()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `values`      | Array of values for each **slice**.                                        |
# | 🏷️ `labels`     | Array of labels for each **slice**.                                        |
# | 🕳️ `hole`       | Size of the center hole (for **donut charts**).                            |
# | 💬 `textinfo`    | Controls displayed info (e.g., `'label'`, `'percent'`, `'value'`).         |
#
# > ✅ **Tip**: Set `hole` (e.g., `0.4`) to create a donut chart.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
labels = ['A', 'B', 'C', 'D']
values = [10, 20, 30, 40]

# Create a pie chart trace
trace = go.Pie(
    labels=labels,
    values=values,
    hole=0.3,  # Create a donut chart
    textinfo='label+percent',  # Display label and percentage
    marker=dict(colors=['blue', 'green', 'red', 'cyan'])
)

# Create a figure and plot it
fig = go.Figure(data=[trace])
fig.show()

# %% [markdown]
# ---
#
# ## 3️⃣ **Statistical Plots**
#
# - 📈 **Definition**:
#   Statistical plots are key for analyzing **data distribution** and **characteristics**.
#   Plotly offers various types, including **histograms**, **box plots**, **violin plots**, and **density plots**.
#
# ---
#
# ## 3️⃣.1️⃣ **Histograms**
#
# - 📊 **Definition**:
#   Histograms show the **frequency distribution** of a dataset by dividing data into **bins** and counting observations per bin.
#   In Plotly, use `go.Histogram()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Histogram()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of data to be **binned**.                                            |
# | 📏 `nbinsx`      | Number of bins for the histogram.                                          |
# | 🛑 `bargap`      | Gap between bars for spacing.                                              |
# | 🎨 `marker`      | Customizes bar appearance (e.g., color, line).                              |
# | 💬 `hovertext`   | Adds custom info on **hover**.                                             |
#
# > ✅ **Tip**: Adjust `nbinsx` to fine-tune the bin size for better distribution visualization.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a histogram trace
fig = go.Figure(data=[go.Histogram(x=data, nbinsx=5,
                                   cumulative={'enabled':True},  # Use a dictionary to set the 'enabled' property to True
                                   marker_color='green',
                                   histnorm='probability density')])  # Normalize to probability density

# Customize the layout
fig.update_layout(
    title_text='Cumulative Histogram',
    xaxis_title='Value',
    yaxis_title='Probability'
)

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 3️⃣.2️⃣ **Box Plots**
#
# - 📊 **Definition**:
#   Box plots visualize the **distribution** of data using a five-number summary: **minimum**, **first quartile**, **median**, **third quartile**, and **maximum**.
#   In Plotly, use `go.Box()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Box()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `y`           | Array of data for the **box plot**.                                        |
# | 🔍 `boxpoints`   | Display individual points: `'outliers'`, `'suspectedoutliers'`, `'all'`, or `False`. |
# | 🎲 `jitter`      | Adds random noise to points for better visualization.                      |
# | 📏 `whiskerwidth` | Controls the width of the **whiskers**.                                    |
# | 🎨 `marker`      | Customizes appearance of points (e.g., color, size).                        |
# | 🖌️ `line`       | Customizes line properties of the box plot (e.g., color, width).            |
#
# > ✅ **Tip**: Use `jitter` with `boxpoints='all'` to avoid overlapping points.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a trace
trace = go.Box(
    y=data,
    boxpoints='all',
    jitter=0.3,
    whiskerwidth=0.5,
    marker=dict(color='green'),
    line=dict(width=2)
)

# Create a figure and plot it
fig = go.Figure(data=[trace])

fig.show()

# %% [markdown]
# ---
#
# ## 3️⃣.3️⃣ **Violin Plots**
#
# - 📊 **Definition**:
#   Violin plots blend **box plots** and **density plots** to display the **distribution** and **probability density** of data.
#   In Plotly, use `go.Violin()` to create violin plots (or combine with ` andato.Box()` for similar effects).
#
# ---
#
# ### 🔧 **Key Parameters of `go.Violin()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `y`           | Array of data for the **violin plot**.                                     |
# | 📍 `box`         | Controls visibility of the inner **box plot** (e.g., `{'visible': True}`).  |
# | 🖌️ `line`       | Customizes line properties (e.g., color, width).                           |
# | 📏 `meanline`    | Controls visibility of the **mean line** (e.g., `{'visible': True}`).      |
# | 🔍 `points`      | Displays individual points: `'all'`, `'outliers'`, or `False`.             |
# | 🎨 `marker`      | Customizes appearance of points (e.g., color, size).                        |
#
# > ✅ **Tip**: Enable `box` and `meanline` for a clearer view of the data’s central tendency.
#
# ---
#
#
# # 3️⃣.3️⃣ Violin Plots
#
# - 📊 **Definition**:
#   Violin plots blend **box plots** and **density plots** to display the **distribution** and **probability density** of data.
#   In Plotly, use `go.Violin()` to create violin plots (or combine with `go.Box()` for similar effects).
#
# ## 🔧 Key Parameters of `go.Violin()`:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `y`           | Array of data for the **violin plot**.                                     |
# | 📍 `box`         | Controls visibility of the inner **box plot** (e.g., `{'visible': True}`).  |
# | 🖌️ `line`       | Customizes line properties (e.g., color, width).                           |
# | 📏 `meanline`    | Controls visibility of the **mean line** (e.g., `{'visible': True}`).      |
# | 🔍 `points`      | Displays individual points: `'all'`, `'outliers'`, or `False`.             |
# | 🎨 `marker`      | Customizes appearance of points (e.g., color, size).                        |
#
# > ✅ **Tip**: Enable `box` and `meanline` for a clearer view of the data’s central tendency.

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a violin plot trace
fig = go.Figure(data=[go.Violin(
    y=data,
    box=dict(visible=True),
    line=dict(color="blue"),
    meanline_visible=True
)])

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 3️⃣.4️⃣ **Density Plots**
#
# - 📊 **Definition**:
#   Density plots visualize the **distribution** of two variables using **contour lines** or **filled contours**.
#   In Plotly, use `go.Histogram2dContour()` for 2D density plots.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Histogram2dContour()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of **x-coordinates**.                                                |
# | 📋 `y`           | Array of **y-coordinates**.                                                |
# | 🎨 `colorscale`  | Sets the **color scale** for the density plot (e.g., `'Viridis'`).         |
# | 🖌️ `contours`   | Customizes **contour lines** and labels (e.g., `{'showlabels': True}`).     |
#
# > ✅ **Tip**: Experiment with `colorscale` to enhance the visual contrast of the density plot.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

# Create a histogram trace
fig = go.Figure(data=[go.Histogram(x=data, nbinsx=5, marker_color='red')])

# Show the plot
fig.show()

# %% [markdown]
# ---
#
# ## 4️⃣ **Subplots and Inset Plots**
#
# - 📊 **Definition**:
#   Subplots and inset plots enable **multiple plots** within a single figure, ideal for **comparisons** and **detailed analysis**.
#
# ---
#
# ### 🛠️ **Creating Subplots with `make_subplots`**
#
# - 📈 **Definition**:
#   Plotly’s `make_subplots()` function creates a **grid layout** for subplots, allowing different plot types in each cell.
#
# ---
#
# ### 🔧 **Key Functions and Parameters**:
#
# | Function/Parameter | Description                                                                 |
# |--------------------|-----------------------------------------------------------------------------|
# | 🛠️ `make_subplots` | Creates a **grid layout** for subplots.                                    |
# | 📏 `rows`          | Number of **rows** in the subplot grid.                                    |
# | 📏 `cols`          | Number of **columns** in the subplot grid.                                 |
# | 🏷️ `subplot_titles` | Titles for each **subplot**.                                              |
# | ➕ `add_trace`     | Adds a plot to a specific **subplot**.                                     |
# | 📍 `row`           | Specifies the **row** for the subplot.                                     |
# | 📍 `col`           | Specifies the **column** for the subplot.                                  |
# | 🎨 `update_layout` | Customizes the overall **layout** (e.g., figure size, titles).              |
#
# > ✅ **Tip**: Use `subplot_titles` to label each subplot clearly for better readability.
#
# ---

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Sample data
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 2, 3, 4, 5]
y3 = [2, 3, 2, 3, 4]

# Create subplots: 2 rows, 2 columns
fig = make_subplots(rows=2, cols=2, subplot_titles=("Scatter Plot", "Line Plot", "Bar Plot"))

# Add traces
fig.add_trace(go.Scatter(x=x, y=y1, mode='markers', name='Scatter'), row=1, col=1)
fig.add_trace(go.Scatter(x=x, y=y2, mode='lines', name='Line'), row=1, col=2)
fig.add_trace(go.Bar(x=x, y=y3, name='Bar'), row=2, col=1)

# Update layout
fig.update_layout(height=600, width=800, title_text="Subplots Example")

# Show plot using fig.show()
fig.show()

# %% [markdown]
# ---
#
# ## 4️⃣.1️⃣ **Inset Plots**
#
# - 📊 **Definition**:
#   Inset plots are **smaller plots** embedded within a main plot, perfect for **highlighting** or **zooming in** on specific data points.
#
# ---
#
# ### 🔧 **Key Concepts**:
#
# - 🛠️ **Creation**: Use Plotly’s `make_subplots` with `subplot_specs` or manually position traces using `xaxis` and `yaxis` domains to create smaller plots inside the main figure.
# - 📍 **Positioning**: Define the inset’s position by setting `domain` (e.g., `[0.6, 0.95]` for x-axis, `[0.6, 0.95]` for y-axis).
# - 🎨 **Customization**: Adjust `xaxis`/`yaxis` properties (e.g., `anchor`, `range`) to control the inset’s appearance and scale.
#
# > ✅ **Tip**: Use inset plots to magnify key data regions while keeping the main plot’s context visible.
#
# ---

# %%
# Sample data
x_main = [1, 2, 3, 4, 5]
y_main = [10, 11, 12, 13, 14]
x_inset = [1, 2, 3]
y_inset = [10, 10.5, 11]

# Create main plot
fig = go.Figure(go.Scatter(x=x_main, y=y_main, mode='lines+markers', name='Main Plot'))

# Add inset plot
fig.add_trace(go.Scatter(x=x_inset, y=y_inset, mode='markers', name='Inset Plot',
                         xaxis='x2', yaxis='y2'))

# Update layout with inset specifications
fig.update_layout(
    xaxis=dict(domain=[0, 0.85]),  # Main plot x-axis
    yaxis=dict(domain=[0, 0.85]),  # Main plot y-axis
    xaxis2=dict(domain=[0.6, 0.95], anchor='y2'),  # Inset x-axis
    yaxis2=dict(domain=[0.6, 0.95], anchor='x2')   # Inset y-axis
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 5️⃣ **3D Plots**
#
# - 📊 **Definition**:
#   3D plots visualize data in **three dimensions**, adding **depth** to data analysis.
#   Plotly supports various 3D plot types, including **scatter plots**, **surface plots**, **mesh plots**, and **cone plots**.
#
# ---
#
# ## 5️⃣.1️⃣ **3D Scatter Plots**
#
# - 📈 **Definition**:
#   3D scatter plots display **data points** in three-dimensional space, revealing their **spatial distribution**.
#   In Plotly, use `go.Scatter3d()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Scatter3d()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of **x-coordinates**.                                                |
# | 📋 `y`           | Array of **y-coordinates**.                                                |
# | 📋 `z`           | Array of **z-coordinates**.                                                |
# | 🎨 `marker`      | Customizes point appearance (e.g., color, size, symbol).                    |
# | 💬 `text` / `hovertext` | Adds labels or info on **hover**.                                   |
# | 🖌️ `mode`       | Sets display mode (e.g., `'markers'`, `'lines'`, `'markers+lines'`).        |
#
# > ✅ **Tip**: Use `marker` to adjust point size or color to highlight patterns in the 3D space.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
z = [10, 11, 12, 13, 14]

# Create a 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers',
                                   marker=dict(size=5, color=z, colorscale='Viridis'))])

# Update layout
fig.update_layout(title='3D Scatter Plot')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 5️⃣.2️⃣ **3D Surface Plots**
#
# - 📊 **Definition**:
#   3D surface plots visualize **three-dimensional data**, with **x** and **y** axes forming a grid and the **z** axis representing height.
#   In Plotly, use `go.Surface()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Surface()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array or grid of **x-coordinates**.                                        |
# | 📋 `y`           | Array or grid of **y-coordinates**.                                        |
# | 📋 `z`           | 2D array of **z-values** (heights).                                        |
# | 🎨 `colorscale`  | Sets the **color scale** for the surface (e.g., `'Viridis'`).              |
# | 🖌️ `contours`   | Customizes **contour lines** on the surface (e.g., `{'x': {'show': True}}`).|
# | 💡 `lighting`    | Adjusts lighting effects (e.g., `{'ambient': 0.8}`).                        |
#
# > ✅ **Tip**: Use `colorscale` to enhance visual contrast and `contours` to highlight specific heights.
#
# ---

# %%
import numpy as np

# Sample data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Create a 3D surface plot
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale='Viridis')])

# Update layout
fig.update_layout(title='3D Surface Plot')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 5️⃣.3️⃣ **3D Mesh Plots**
#
# - 📊 **Definition**:
#   3D mesh plots create a **wireframe representation** of three-dimensional data, connecting points to form a mesh.
#   In Plotly, use `go.Mesh3d()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Mesh3d()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of **x-coordinates**.                                                |
# | 📋 `y`           | Array of **y-coordinates**.                                                |
# | 📋 `z`           | Array of **z-coordinates**.                                                |
# | 🔗 `i`, `j`, `k` | Arrays defining triangle connectivity for the mesh.                        |
# | 🎨 `colorscale`  | Sets the **color scale** for the mesh (e.g., `'Plasma'`).                  |
# | 💡 `lighting`    | Adjusts lighting effects (e.g., `{'ambient': 0.7}`).                        |
#
# > ✅ **Tip**: Define `i`, `j`, `k` carefully to ensure correct triangle connections for the mesh.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
z = [10, 11, 12, 13, 14]

# Create a 3D mesh plot
fig = go.Figure(data=[go.Mesh3d(x=x, y=y, z=z, color='lightblue', opacity=0.50)])

# Update layout
fig.update_layout(title='3D Mesh Plot')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 5️⃣.4️⃣ **3D Cone Plots**
#
# - 📊 **Definition**:
#   3D cone plots visualize **vector fields** in three dimensions, ideal for representing **flow data**.
#   In Plotly, use `go.Cone()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Cone()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `x`           | Array of **x-coordinates** for cone origins.                               |
# | 📋 `y`           | Array of **y-coordinates** for cone origins.                               |
# | 📋 `z`           | Array of **z-coordinates** for cone origins.                               |
# | ➡️ `u`, `v`, `w` | Arrays defining **vector components** (direction and magnitude).            |
# | 🎨 `colorscale`  | Sets the **color scale** for cones (e.g., `'Blues'`).                       |
# | 📏 `sizeref`     | Scales cone size relative to vector magnitude.                              |
#
# > ✅ **Tip**: Adjust `sizeref` to control cone size for better visualization of vector magnitudes.
#
# ---

# %%
# Sample data
x, y, z = np.meshgrid(np.arange(-10, 10, 2),
                      np.arange(-10, 10, 2),
                      np.arange(-10, 10, 2))
u = np.cos(x)
v = np.sin(y)
w = np.cos(z)

# Create a 3D cone plot
fig = go.Figure(data=go.Cone(x=x.flatten(), y=y.flatten(), z=z.flatten(),
                             u=u.flatten(), v=v.flatten(), w=w.flatten(),
                             colorscale='Blues'))

# Update layout
fig.update_layout(title='3D Cone Plot')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 6️⃣ **Geographic Plots**
#
# - 📊 **Definition**:
#   Geographic plots in Plotly visualize data across **geographic locations**, revealing **spatial distributions** and **trends**.
#
# ---
#
# ## 6️⃣.1️⃣ **Choropleth Maps**
#
# - 📈 **Definition**:
#   Choropleth maps use **color-shading** to represent data across geographic areas (e.g., countries, regions) based on a data variable.
#   In Plotly, use `go.Choropleth()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Choropleth()`**:
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 📋 `locations`   | Array of location identifiers (e.g., country codes, region names).          |
# | 📋 `z`           | Array of values determining the **color intensity**.                       |
# | 🎨 `colorscale`  | Sets the **color scale** for shading (e.g., `'Viridis'`).                   |
# | 🗺️ `locationmode` | Defines location format (e.g., `'ISO-3'`, `'country names'`).              |
# | 💬 `text` / `hovertext` | Adds labels or info on **hover**.                                   |
# | 🖌️ `marker`      | Customizes boundaries (e.g., line color, width).                            |
#
# > ✅ **Tip**: Ensure `locations` matches `locationmode` for accurate mapping.
#
# ---

# %%
import plotly.graph_objects as go

# Sample data
locations = ['USA', 'CAN', 'MEX']
values = [100, 200, 300]

# Create choropleth map
fig = go.Figure(data=go.Choropleth(
    locations=locations,
    z=values,
    locationmode='country names',
    colorscale='Viridis',
    marker_line_color='darkgray',
    marker_line_width=0.5,
))

# Update layout
fig.update_layout(title_text='Choropleth Map Example')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 6️⃣.3️⃣ **Scatter Maps**
#
# - 🗺️ **Definition**:
#   Scatter Maps plot **individual data points** on a **geographic map**, using **latitude and longitude**.
#   Ideal for showing **locations**, **events**, or **distribution patterns** across a map.
#   In Plotly, this is done using `go.Scattermapbox()` for **Mapbox-based scatter plots**.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Scattermapbox()`**:
#
# | Parameter           | Description                                                                 |
# |---------------------|-----------------------------------------------------------------------------|
# | 🌐 `lat`            | List of **latitude coordinates** for the data points.                        |
# | 🌐 `lon`            | List of **longitude coordinates** for the data points.                       |
# | 🎯 `mode`           | Display style: `'markers'`, `'text'`, `'lines+markers'`, etc.               |
# | 🖍️ `marker`         | Customize **size**, **color**, **opacity**, and **symbol** of the markers. |
# | 💬 `text`           | Hover labels or point annotations.                                           |
# | 🗺️ `mapbox_style`   | Sets the **background map style** (e.g., `'open-street-map'`, `'satellite'`).|
# | 🧭 `zoom`, `center` | Controls **initial zoom level** and **center point** of the map.             |
#
# > ✅ **Tip**: You must set your Mapbox access token using `px.set_mapbox_access_token("your_token")` or use free styles like `'open-street-map'`.
#
# ---

# %%
# Sample data
lon = [-74.006, -118.2437, -122.4194]
lat = [40.7128, 34.0522, 37.7749]
texts = ['New York', 'Los Angeles', 'San Francisco']

# Create scatter map
fig = go.Figure(data=go.Scattergeo(
    lon=lon,
    lat=lat,
    text=texts,
    mode='markers+text',
    marker=dict(size=8, color='blue'),
))

# Update layout
fig.update_layout(title='Scatter Map Example')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 6️⃣.4️⃣ **Density Maps**
#
# - 🌐 **Definition**:
#   Density Maps visualize the **concentration or intensity** of data points across **geographic areas**.
#   Useful for highlighting **hotspots** or **frequented regions**.
#   In Plotly, use `px.density_mapbox()` from **Plotly Express** for quick and effective density plotting.
#
# ---
#
# ### 🔧 **Key Parameters of `px.density_mapbox()`**:
#
# | Parameter           | Description                                                                 |
# |---------------------|-----------------------------------------------------------------------------|
# | 🌐 `lat`            | List of **latitude values** of the data points.                              |
# | 🌐 `lon`            | List of **longitude values** of the data points.                             |
# | 🔢 `z`              | Optional. Numeric values used for **weighting** the density.                 |
# | 🎨 `radius`         | Controls the **spread of each point** on the map (in pixels).                |
# | 🗺️ `mapbox_style`   | Background map style (e.g., `'stamen-terrain'`, `'open-street-map'`).       |
# | 🔍 `zoom`           | Initial **zoom level** of the map.                                           |
# | 📌 `center`         | Dictionary to **center the map** on a specific lat/lon point.                |
#
# > ✅ **Tip**: The `radius` parameter significantly affects the **smoothness vs sharpness** of the density zones.
# > 🆓 **No Mapbox token required** when using `'open-street-map'` as `mapbox_style`.
#
# ---

# %%
import plotly.graph_objects as go

# 🌐 Sample geographic data
lon = [-74.006, -118.2437, -122.4194, -87.6298]   # NYC, LA, SF, Chicago
lat = [40.7128, 34.0522, 37.7749, 41.8781]

# 🔥 Create Density Map with new API
fig = go.Figure(go.Densitymap(
    lat=lat,
    lon=lon,
    radius=10
))

# 🗺️ Update layout for Maplibre-compatible map
fig.update_layout(
    mapbox_style="open-street-map",   # Open source, no token required
    mapbox_center={"lon": -100, "lat": 39},
    mapbox_zoom=3,
    title='📍 US Cities - Density Map (Maplibre)'
)

# 🚀 Show the interactive plot
fig.show()

# %% [markdown]
# ---
#
# ## 7️⃣ **Time Series Analysis**
#
# - 📅 **Definition**:
#   Time series analysis in Plotly focuses on **visualizing data over time**, enabling the detection of **trends**, **patterns**, and **seasonality**.
#   Common chart types: **Line charts**, **Candlestick charts**, **Bar charts**, and **Scatter plots**.
#
# ---
#
# ## 7️⃣.1️⃣ **Line Charts**
#
# - 📈 **Definition**:
#   Line charts are used to display **continuous data** over time, making it easy to spot **trends**, **growth**, or **fluctuations**.
#   In Plotly, use `go.Scatter()` with `mode='lines'` or `px.line()` from Plotly Express.
#
# ---
#
# ### 🔧 **Key Parameters for `go.Scatter()` (Line Mode)**
#
# | Parameter     | Description                                                                 |
# |---------------|-----------------------------------------------------------------------------|
# | 🕒 `x`        | Time or sequential data (e.g., dates, timestamps).                          |
# | 🔢 `y`        | Numeric values that vary over time.                                          |
# | 🧭 `mode`     | Use `'lines'` for time series (`'lines+markers'` adds points).               |
# | 🎨 `line`     | Dictionary to customize **color**, **width**, and **dash** style.            |
# | 💬 `name`     | Name of the trace (shown in legend).                                         |
# | 🛠️ `hoverinfo` | Customize what info shows on hover.                                         |
#
# > ✅ **Tip**: Use `mode='lines+markers'` to highlight each data point along the line.
#
# ---

# %%
# Sample data
dates = ['2021-01-01', '2021-02-01', '2021-03-01']
values = [10, 15, 13]

# Create line chart
fig = go.Figure(data=go.Scatter(x=dates, y=values, mode='lines'))

# Update layout
fig.update_layout(title='Line Chart Example', xaxis_title='Date', yaxis_title='Value')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 7️⃣.2️⃣ **Candlestick Charts**
#
# - 💹 **Definition**:
#   Candlestick charts are primarily used in **financial analysis** to display the **Open**, **High**, **Low**, and **Close** (OHLC) values of a financial instrument over time.
#   Ideal for **stock prices**, **crypto trading**, or any asset with time-bound price movements.
#   In Plotly, use `go.Candlestick()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Candlestick()`**
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 🕒 `x`           | Time-based data (e.g., dates, timestamps).                                  |
# | 🟢 `open`        | Opening price of the asset.                                                  |
# | 🔼 `high`        | Highest price reached in the time period.                                    |
# | 🔽 `low`         | Lowest price in the time period.                                             |
# | 🔴 `close`       | Closing price at the end of the time period.                                 |
# | 🎨 `increasing`  | Style customization for bullish candles (e.g., color, line width).            |
# | 🎨 `decreasing`  | Style customization for bearish candles.                                     |
#
# > ✅ **Tip**: Candlestick charts are especially useful when combined with **hover info**, **volume bars**, and **technical indicators** for deeper analysis.
#
# ---

# %%
# Sample data
dates = ['2021-01-01', '2021-02-01', '2021-03-01']
open_data = [100, 110, 105]
high_data = [110, 115, 108]
low_data = [90, 105, 100]
close_data = [105, 112, 107]

# Create candlestick chart
fig = go.Figure(data=[go.Candlestick(x=dates, open=open_data, high=high_data, low=low_data, close=close_data)])

# Update layout
fig.update_layout(title='Candlestick Chart Example', xaxis_title='Date', yaxis_title='Price')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 7️⃣.3️⃣ **Bar Charts**
#
# - 📊 **Definition**:
#   Bar charts are used in time series analysis to represent data across **discrete time intervals** such as **months**, **quarters**, or **years**.
#   They're particularly effective when comparing values across **grouped time categories**.
#   In Plotly, use `go.Bar()` or `px.bar()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Bar()` (Time Series Context)**
#
# | Parameter     | Description                                                                 |
# |---------------|-----------------------------------------------------------------------------|
# | 🕒 `x`        | Time or categorical periods (e.g., `'Jan'`, `'Q1'`, `'2023'`).               |
# | 🔢 `y`        | Numerical values for each time interval.                                     |
# | 🧱 `name`     | Label for the trace (used in the legend).                                    |
# | 🎨 `marker`   | Customize **color**, **line width**, or **pattern** of the bars.             |
# | 🪄 `opacity`  | Controls transparency of bars (for stacked or overlapped charts).            |
# | 🗂️ `barmode`  | `'group'`, `'stack'`, or `'overlay'` — useful when comparing categories.     |
#
# > ✅ **Tip**: Use bar charts for **seasonal comparisons**, **sales over months**, or **quarterly financial summaries**.
#
# ---

# %%
# Sample data
dates = ['2021-01', '2021-02', '2021-03']
values = [10, 15, 13]

# Create bar chart
fig = go.Figure(data=go.Bar(x=dates, y=values))

# Update layout
fig.update_layout(title='Bar Chart Example', xaxis_title='Month', yaxis_title='Value')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 7️⃣.4️⃣ **Scatter Plots**
#
# - 🔍 **Definition**:
#   Scatter plots in time series analysis are used to visualize **individual data points over time**, helping to identify **distribution patterns**, **anomalies**, or **relationships** between variables.
#   In Plotly, use `go.Scatter()` with `mode='markers'` or `px.scatter()`.
#
# ---
#
# ### 🔧 **Key Parameters of `go.Scatter()` (Scatter Mode)**
#
# | Parameter     | Description                                                                 |
# |---------------|-----------------------------------------------------------------------------|
# | 🕒 `x`        | Time-based values (e.g., dates, timestamps).                                |
# | 🔢 `y`        | Numeric values (e.g., stock prices, sensor readings).                       |
# | 🎯 `mode`     | Use `'markers'` for scatter; combine with `'lines'` for hybrid charts.      |
# | 🧿 `marker`   | Customize size, color, symbol of each point.                                |
# | 🧾 `text`     | Adds annotations or descriptions per data point.                            |
# | 🧪 `hoverinfo`| Define what appears when hovering over a point.                             |
#
# > ✅ **Tip**: Scatter plots are great for **highlighting outliers**, **event markers**, or **correlation trends** in time-based data.
#
# ---

# %%
# Sample data
dates = ['2021-01-01', '2021-02-01', '2021-03-01']
values = [10, 15, 13]

# Create scatter plot
fig = go.Figure(data=go.Scatter(x=dates, y=values, mode='markers'))

# Update layout
fig.update_layout(title='Scatter Plot Example', xaxis_title='Date', yaxis_title='Value')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 8️⃣ **Interactive Features**
#
# - 🧠 **Definition**:
#   Plotly supports rich **interactive capabilities** that enhance **data exploration**, improve **user engagement**, and make visualizations more **informative and dynamic**.
#   Common interactive elements include **hover text**, **zooming**, **tooltips**, **sliders**, **dropdowns**, and more.
#
# ---
#
# ## 8️⃣.1️⃣ **Hover Text**
#
# - 🖱️ **Definition**:
#   Hover text displays **contextual information** when the user **hovers over data points** on the plot.
#   It enhances interpretability without cluttering the chart visually.
#   Used in almost all Plotly chart types via `text`, `hovertext`, and `hoverinfo`.
#
# ---
#
# ### 🔧 **Key Parameters for Hover Customization**
#
# | Parameter       | Description                                                                  |
# |------------------|------------------------------------------------------------------------------|
# | 💬 `text`        | Specifies text labels for data points (shown on hover by default).           |
# | ℹ️ `hovertext`   | Alternative to `text`; offers more control for hover-only content.           |
# | 🎯 `hoverinfo`   | Controls what info appears on hover (e.g., `'x+y+text'`, `'skip'`).          |
# | ✨ `hovertemplate`| Fully customizes the hover appearance using template strings.                |
# | 📌 `customdata`  | Allows embedding additional data for hover use via templates.                |
#
# > ✅ **Tip**: Use `hovertemplate` for **precise formatting**, including HTML and line breaks.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot with hover text
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', text=['A', 'B', 'C', 'D'], hovertext=['Label A', 'Label B', 'Label C', 'Label D']))

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 8️⃣.2️⃣ **Click Events**
#
# - 🔘 **Definition**:
#   Click events enable **user interaction** with the plot, allowing users to trigger specific **actions** or **responses** (such as updates, filtering, or additional information display).
#   These are often integrated with **Plotly Dash** or JavaScript for enhanced functionality.
#
# ---
#
# ### 🔧 **Key Features of Click Events**
#
# | Feature          | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 🖱️ `clickData`   | Captures information about the point or trace clicked.                       |
# | 🖱️ `relayoutData`| Captures changes in layout triggered by click events (e.g., zoom, axis changes). |
# | 🖱️ `clickmode`   | Defines the mode of the click (e.g., `'event'`, `'select'`, `'none'`).     |
#
# > ✅ **Tip**: Use click events to trigger **dashboards** that update with detailed views or charts.
#
# ---
#
# ## 8️⃣.3️⃣ **Dropdowns**
#
# - 📋 **Definition**:
#   Dropdown menus are interactive widgets that allow users to **select different views** or **configurations** of the plot.
#   They provide an easy way to toggle between various datasets, chart types, or options in one plot.
#   In Plotly, dropdowns can be created using **`updatemenus`**.
#
# ---
#
# ### 🔧 **Key Parameters for Dropdown Menus**
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 🔽 `buttons`     | List of buttons that define options for the dropdown menu.                  |
# | 🎨 `active`      | Defines the default button (index) that's selected when the plot is first loaded. |
# | ⚙️ `x`, `y`      | Positioning of the dropdown on the plot (relative to the chart area).      |
# | 🧳 `showactive`  | Specifies whether the selected button is highlighted in the dropdown.       |
#
# > ✅ **Tip**: Use dropdowns for **dynamic charts** that need to change datasets, chart types, or other visual aspects without reloading the plot.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y1 = [10, 15, 13, 17]
y2 = [16, 5, 11, 9]

# Create initial scatter plot
fig = go.Figure(data=[go.Scatter(x=x, y=y1, mode='lines+markers', name='Dataset 1')])

# Add dropdown menu
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(label="Dataset 1", method="update", args=[{"y": [y1]}]),
                dict(label="Dataset 2", method="update", args=[{"y": [y2]}])
            ]),
        )
    ]
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 8️⃣.4️⃣ **Sliders**
#
# - 🎚️ **Definition**:
#   Sliders allow users to **adjust parameters dynamically**, making it easy to interact with the data, such as **filtering by time**, **modifying values**, or **adjusting thresholds** in a plot.
#   They are especially useful in **time series analysis** or when visualizing changes over time or conditions.
#
# ---
#
# ### 🔧 **Key Parameters for Sliders**
#
# | Parameter        | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | 🔘 `steps`       | Defines the discrete steps in the slider (e.g., specific time intervals).    |
# | 🔑 `currentvalue`| Displays the current value of the slider, often in text form on the plot.    |
# | 🎯 `pad`         | Adds padding around the slider to control spacing.                          |
# | 🔄 `transition`  | Controls the transition effect when the slider moves (e.g., **duration**).   |
# | 🔀 `rangeslider` | Enables a range slider that allows selecting a range of values (useful for zooming). |
#
# > ✅ **Tip**: Combine sliders with **animations** or **click events** to create interactive, dynamic dashboards or exploratory tools.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines+markers'))

# Add slider
fig.update_layout(
    sliders=[{
        'steps': [{'label': 'Step 1', 'method': 'update', 'args': [{'y': [[10, 15, 13, 17]]}]},
                  {'label': 'Step 2', 'method': 'update', 'args': [{'y': [[5, 10, 8, 12]]}]}]
    }]
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 8️⃣.5️⃣ **Buttons**
#
# - 🔘 **Definition**:
#   Buttons are interactive elements that allow users to trigger **specific actions** in the plot, such as **changing chart types**, **filtering data**, or **updating the plot's appearance**.
#   Buttons are often used in conjunction with **dropdowns**, **sliders**, or **click events** to create fully interactive visualizations.
#
# ---
#
# ### 🔧 **Key Parameters for Buttons**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🔲 `label`        | The text or label displayed on the button.                                  |
# | 🔄 `method`       | Defines the action to be taken when the button is clicked (e.g., `'relayout'`, `'restyle'`). |
# | 📝 `args`         | The arguments passed to the method, such as chart configuration or data to update. |
# | 🎨 `visible`      | Defines the visibility of the button on the plot (e.g., showing or hiding it). |
# | 🎨 `color`        | Controls the appearance of the button (e.g., background color).             |
#
# > ✅ **Tip**: Combine buttons with **multiple chart updates** (e.g., toggling between line charts and bar charts) for rich interactivity.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines+markers'))

# Add buttons
fig.update_layout(
    updatemenus=[dict(
        type="buttons",
        direction="left",
        buttons=list([
            dict(label="Scatter", method="update", args=[{"mode": "markers"}]),
            dict(label="Line", method="update", args=[{"mode": "lines"}])
        ]),
    )]
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 9️⃣ **Animations**
#
# - 🎬 **Definition**:
#   Animations in Plotly are used to visualize **changes over time** or across **different categories** by smoothly transitioning between different states of the plot.
#   They can provide dynamic insights, such as showing the progression of data points, changes in distributions, or how variables interact over time.
#   Animations are typically controlled using **frames** and **layout updatemenus**.
#
# ---
#
# ### 🔧 **Key Parameters for Animations**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🎞️ `frames`       | A list of frames that define the states of the plot (each frame represents a time step or category). |
# | 🔄 `animation`     | Specifies the type of animation (e.g., **duration**, **easing**).            |
# | ⏱️ `updatemenus`  | Controls the **start**, **pause**, and **reset** functionality for animations. |
# | 🧳 `transition`    | Defines the **transition duration** and **easing function** for the animation. |
# | 🌀 `animate`       | A boolean that enables or disables animation for specific elements in the plot. |
#
# > ✅ **Tip**: Use animations to represent **time-based changes** (e.g., changes in stock prices over months) or **dynamic transitions** between categories (e.g., switching between regions or products).
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create figure with frames for animation
fig = go.Figure(
    data=[go.Scatter(x=x, y=y, mode='lines+markers')],
    layout=go.Layout(
        title="Animated Plot",
        updatemenus=[dict(type="buttons", showactive=False, buttons=[dict(label="Play", method="animate", args=[None])])],
    ),
    frames=[go.Frame(data=[go.Scatter(x=[1, 2, 3, 4], y=[10, 15, 13, 17])], name="frame1"),
            go.Frame(data=[go.Scatter(x=[1, 2, 3, 4], y=[5, 10, 8, 12])], name="frame2")]
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 🔟 **Customizations**
#
# - 🎨 **Definition**:
#   Plotly offers extensive **customization options** for adjusting the overall layout and appearance of the plot. This includes everything from **plot titles** to **axes**, **legends**, **colors**, **margins**, and **gridlines**.
#   Customizations can be applied globally to the plot or individually to each trace.
#
# ---
#
# ## 🔟.1️⃣ **Layout Object**
#
# - 🖼️ **Definition**:
#   The **layout object** controls the general configuration of the plot, such as the **title**, **axes**, **legend**, and other structural elements.
#   It is used to modify the **visual appearance** of the plot while maintaining the data representation intact.
#
# ---
#
# ### 🔧 **Key Parameters of the Layout Object**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🏷️ `title`        | Defines the **main title** of the plot.                                     |
# | 📏 `xaxis`, `yaxis` | Defines the configuration of the **x** and **y** axes (e.g., labels, ranges, tick marks). |
# | 🔲 `legend`        | Customizes the **legend** (e.g., position, orientation, visibility).        |
# | 📐 `margin`        | Controls the **margins** around the plot area (e.g., top, bottom, left, right). |
# | 🗺️ `mapbox`        | Configures **mapbox-style** plots (used in geographic plots).               |
# | 🎛️ `hovermode`     | Controls the **hover behavior** (e.g., `'closest'`, `'x unified'`, `'y unified'`). |
#
# > ✅ **Tip**: Customize the layout to improve **visual clarity**, enhance **readability**, or tailor the plot for specific presentation needs.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines+markers'))

# Customize layout
fig.update_layout(
    title='Custom Plot Title',
    xaxis_title='X Axis Title',
    yaxis_title='Y Axis Title',
    legend_title='Legend Title',
    font=dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 🔟.2️⃣ **Trace-Specific Customizations**
#
# - 🖋️ **Definition**:
#   **Trace-specific customizations** allow users to adjust the appearance of individual data series (or traces) in a plot.
#   These customizations include styling elements such as **markers**, **lines**, **text labels**, and **hover text**, allowing for a detailed and personalized visual representation of each trace in the plot.
#
# ---
#
# ### 🔧 **Key Customization Attributes for Traces**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🔵 `marker`        | Customizes the **appearance** of data points (e.g., size, color, symbol).    |
# | 🖌️ `line`          | Adjusts the **line style** (e.g., width, color, dash).                       |
# | 💬 `text`          | Adds **text labels** to each data point.                                    |
# | 💬 `hovertext`     | Specifies the **hover text** that appears when a user hovers over a data point. |
# | 📏 `mode`          | Controls the **plot mode** (e.g., `'lines'`, `'markers'`, `'text'`).         |
# | 🔘 `fill`          | Defines the **area fill** for line traces (e.g., `'tonexty'` for filling under the line). |
#
# > ✅ **Tip**: Use **`text`** and **`hovertext`** to provide additional **information** without cluttering the plot visually, especially in **scatter plots** or **line charts**.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot with custom markers
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', marker=dict(size=10, color='blue', symbol='circle')))

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 🔟.3️⃣ **Colormaps**
#
# - 🌈 **Definition**:
#   **Colormaps** are used to map **numeric data** to a range of colors, providing a visual representation of data values.
#   The **colorscale** attribute in Plotly controls how numeric values are translated into colors, enhancing the understanding of data patterns, such as intensity or distribution.
#
# ---
#
# ### 🔧 **Key Parameters for Colormaps**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🎨 `colorscale`    | Defines the **color scale** to be used (e.g., `'Viridis'`, `'Cividis'`).     |
# | ⚙️ `zmin` / `zmax` | Sets the **range** of data values to map to the colorscale.                  |
# | 🔵 `cmin` / `cmax` | Determines the **data range** for color mapping when using `colorbar`.       |
# | 🌟 `colorbar`      | Customizes the **colorbar** appearance (e.g., title, tick marks, orientation). |
#
# > ✅ **Tip**: Use **diverging colormaps** (e.g., `'RdBu'`) for data with both **positive** and **negative** values to highlight differences.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot with colormap
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', marker=dict(size=10, color=y, colorscale='Viridis')))

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 🔟.4️⃣ **Annotations**
#
# - ✍️ **Definition**:
#   **Annotations** allow you to add **text labels** or **descriptions** to specific coordinates on the plot.
#   They help to highlight key points, provide additional context, or draw attention to important features in the visualization.
#
# ---
#
# ### 🔧 **Key Parameters for Annotations**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 📝 `text`          | The **text** to display at the annotation location.                          |
# | 📍 `x` / `y`       | The **coordinates** (x and y) for the annotation on the plot.               |
# | 🎨 `font`          | Customizes the **font** of the annotation (e.g., size, color, family).      |
# | ⛔ `showarrow`     | Determines whether to display an **arrow** pointing to the annotation.      |
# | 🔲 `arrowhead`     | Controls the **shape** and **size** of the annotation arrow.                |
# | 🖌️ `align`         | Defines the **text alignment** (e.g., `'center'`, `'left'`, `'right'`).    |
# | 🎨 `bgcolor`       | Sets the **background color** of the annotation box.                        |
#
# > ✅ **Tip**: Use annotations to **highlight trends**, **explain outliers**, or **emphasize specific data points** for better insight.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot with annotation
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers'))

# Add annotation
fig.add_annotation(x=2, y=15, text="Annotation Example", showarrow=True, arrowhead=1)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 🔟.5️⃣ **Shapes**
#
# - 🔲 **Definition**:
#   **Shapes** such as **lines**, **rectangles**, and **circles** can be added to the plot to highlight areas, create boundaries, or emphasize specific data points.
#   These shapes are controlled using the `layout.shapes` attribute in Plotly and can help enhance the overall understanding of the plot's context.
#
# ---
#
# ### 🔧 **Key Parameters for Shapes**
#
# | Parameter         | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | 🔲 `type`          | Defines the **shape type** (e.g., `'line'`, `'circle'`, `'rect'`).           |
# | 📏 `x0` / `y0`     | Coordinates of the starting point of the shape (e.g., for lines or rectangles). |
# | 📏 `x1` / `y1`     | Coordinates of the ending point of the shape (e.g., for lines or rectangles). |
# | 🖌️ `line`          | Customizes the **line style** of the shape (e.g., width, color).            |
# | 🔲 `fillcolor`     | Sets the **fill color** for shapes that enclose an area (e.g., rectangles).  |
# | 🔘 `opacity`        | Adjusts the **opacity** of the shape, making it more or less transparent.   |
# | 🔄 `layer`          | Specifies the **layer** (e.g., `'below'`, `'above'`) to control the shape's rendering order. |
#
# > ✅ **Tip**: Use **rectangles** to highlight areas on a plot or **lines** to draw **boundaries** or **guidelines**.
#
# ---

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

# Create scatter plot with custom shape
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers'))

# Add rectangle shape
fig.update_layout(
    shapes=[
        dict(
            type="rect",
            x0=1, x1=3, y0=10, y1=15,
            line=dict(color="RoyalBlue"),
            fillcolor="LightSkyBlue",
        ),
    ]
)

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 1️⃣1️⃣ **Plotly Express**
#
# - 🌟 **Definition**:
#   **Plotly Express** is a high-level interface designed for creating **complex plots quickly** and with minimal code. It is particularly useful when working with **Pandas DataFrames**, enabling seamless integration between the data and the visualization. Plotly Express abstracts many of the complexities in plot creation, making it an ideal choice for quick and efficient data exploration.
#
# ---
#
# ## 1️⃣1️⃣.1️⃣ **Key Functions**
#
# Plotly Express offers various functions to create different types of plots. Below are some of the key functions:
#
# - 📈 **`px.line()`**: Creates **line charts** to visualize trends over time or categories.
# - 📍 **`px.scatter()`**: Creates **scatter plots** to show the relationship between two continuous variables.
# - 📊 **`px.bar()`**: Creates **bar charts** to represent categorical data.
# - 📊 **`px.histogram()`**: Creates **histograms** to display the distribution of a single variable.
# - 📦 **`px.box()`**: Creates **box plots** to summarize data distribution and detect outliers.
# - 🎻 **`px.violin()`**: Creates **violin plots** to show data distribution, combining aspects of box plots and kernel density plots.
# - 🌡️ **`px.heatmap()`**: Creates **heatmaps** to represent data values with colors in a 2D matrix.
# - 🔗 **`px.scatter_matrix()`**: Creates **scatter matrix plots** to show relationships between multiple variables.
# - 🔄 **`px.parallel_categories()`**: Creates **parallel category plots** for visualizing categorical data relationships.
# - 📏 **`px.parallel_coordinates()`**: Creates **parallel coordinate plots** for multidimensional data exploration.
# - 🌞 **`px.sunburst()`**: Creates **sunburst plots** to visualize hierarchical data as a series of concentric rings.
# - 🌳 **`px.treemap()`**: Creates **treemaps** to represent hierarchical data with nested rectangles.
# - 🌍 **`px.choropleth()`**: Creates **choropleth maps** to display geographic data using color shading.
# - 🌍 **`px.scatter_geo()`**: Creates **scatter geo maps** to visualize geographical data points.
# - 🌍 **`px.density_mapbox()`**: Creates **density maps** on a **mapbox**, visualizing concentrations of data points on a map.
#
# > ✅ **Tip**: Plotly Express makes plotting faster and more intuitive, especially when dealing with **Pandas DataFrames**. The functions are optimized for common data visualization tasks, reducing the need for detailed configuration.
#
# ---

# %%
import plotly.express as px
import pandas as pd

# Sample data
df = pd.DataFrame({
    'x': [1, 2, 3, 4],
    'y': [10, 15, 13, 17],
    'category': ['A', 'B', 'A', 'B']
})

# Create scatter plot
fig = px.scatter(df, x='x', y='y', color='category', title='Scatter Plot with Plotly Express')

# Show plot
fig.show()

# %% [markdown]
# ---
#
# ## 1️⃣2️⃣ **Integrating Plotly with Dash**
#
# - 🌐 **Definition**:
#   **Dash** is a Python framework for building **interactive web applications**. It integrates seamlessly with **Plotly** to provide dynamic, interactive visualizations. Dash apps can be used for a variety of purposes, such as **data analysis** and **visual storytelling**. The framework allows users to create interactive dashboards that enable real-time data exploration with Plotly charts.
#
# ---
#
# ## 1️⃣2️⃣.1️⃣ **Core Components**
#
# Dash provides essential components for building web apps. Some key components include:
#
# - 🖥️ **`dash.Dash()`**:
#   Initializes the Dash app, which acts as the container for all components. This is the main entry point when building a Dash app.
#
#   ```python
#   app = dash.Dash(__name__)
#   ```
#
# - 📝 **`dash.html`**:
#   Provides a set of **HTML components** (e.g., `<div>`, `<h1>`, `<p>`) to define the structure and layout of the app. These components are used to organize the page and add static content like headers and text.
#
#   ```python
#   import dash.html as html
#   ```
#
# - 📊 **`dash.dcc`**:
#   Contains **Plotly Dash components** (e.g., `Graph`, `Dropdown`, `Slider`) for interactive visualizations and elements. This allows integration of Plotly charts and widgets for user interaction.
#
#   ```python
#   import dash.dcc as dcc
#   ```
#
# ---
#
# ## 1️⃣2️⃣.2️⃣ **Layout**
#
# The **layout** of a Dash app defines the **structure and appearance** of the application. It consists of a hierarchy of Dash components that arrange the content on the webpage.
#
# - 🧩 **Layout Components**:
#   The layout consists of Dash components, which can be nested inside each other. These components include:
#   - **HTML elements**: For static content.
#   - **Plotly graphs**: For interactive visualizations.
#   - **Interactive elements**: Such as buttons, sliders, and dropdowns.
#
# - 🎨 **Example Layout**:
#   A basic layout might look like this:
#
#   ```python
#   app.layout = html.Div([
#       html.H1("My Dash App"),
#       dcc.Graph(figure=my_figure),
#       dcc.Slider(min=0, max=10, step=1, value=5)
#   ])
#   ```
#
# - 🔄 **Dynamic Layout**:
#   You can dynamically update the layout using **callback functions** in Dash, enabling real-time updates of plots or other elements based on user interactions (e.g., selecting a value from a dropdown or adjusting a slider).
#
# > ✅ **Tip**: Dash's layout system allows for easy integration with Plotly visualizations and offers the flexibility to design interactive, real-time data dashboards.
#
# ---

# %% [markdown]
# ---
#
# ## 1️⃣2️⃣.3️⃣ **Callbacks**
#
# - 🔄 **Definition**:
#   **Callbacks** in Dash define **interactions** between components in a Dash app. They enable **dynamic updates** based on user input, such as clicking a button, selecting an item from a dropdown, or moving a slider. Callbacks are the heart of interactivity in Dash applications, allowing the plot and other elements to react to changes in real time.
#
# ---
#
# ### 🔧 **Key Components of a Callback**
#
# 1. **Input**:
#    The component that triggers the callback. This is typically a user interaction, like changing a slider value, selecting a dropdown option, or clicking a button.
#
# 2. **Output**:
#    The component that updates in response to the input. This could be a graph, text, or any other component that needs to change dynamically.
#
# 3. **State (optional)**:
#    Used to pass additional information to the callback that doesn't trigger updates by itself, but helps the callback function process data.
#
# ---
#
# ### 🔧 **Callback Syntax**
#
# A basic Dash callback follows this structure:
#
# ```python
# @app.callback(
#     Output('output-component-id', 'property'),
#     Input('input-component-id', 'property')
# )
# def update_output(input_value):
#     return f"Updated value: {input_value}"
# ```
#
# - **`@app.callback`**:
#   The decorator used to define a callback in Dash.
#
# - **`Output()`**:
#   Specifies the component and property that will be updated by the callback.
#
# - **`Input()`**:
#   Specifies the component and property that will trigger the callback when changed.
#
# - **`State()`**:
#   Optional parameter used to pass additional data to the callback without triggering the update.
#
# ---
#
# ### 🎯 **Example Callback: Updating Graph Based on Slider**
#
# Here’s an example of using a callback to update a Plotly graph based on a slider input:
#
# ```python
# @app.callback(
#     Output('graph', 'figure'),
#     Input('slider', 'value')
# )
# def update_graph(slider_value):
#     # Update the figure based on slider value
#     return {
#         'data': [{
#             'x': [1, 2, 3, 4],
#             'y': [slider_value * i for i in range(1, 5)],
#             'type': 'line'
#         }],
#         'layout': {
#             'title': f'Graph updated with value: {slider_value}'
#         }
#     }
# ```
#
# In this example:
# - The **slider**'s value triggers the callback.
# - The **graph** updates dynamically based on the slider value.
#
# > ✅ **Tip**: Dash callbacks enable the creation of **interactive dashboards** where users can explore data through intuitive components like sliders, dropdowns, and buttons.
#
# ---

# %%
from dash.dependencies import Input, Output

# Define callback for interactive update
@app.callback(
    Output('example-graph', 'figure'),
    [Input('dropdown', 'value')]
)
def update_graph(selected_value):
    # Update plot based on selected value
    fig = px.scatter(df, x='x', y='y', color='category')
    return fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 from dash.dependencies import Input, Output
#       3 # Define callback for interactive update
# ----> 4 @app.callback(
#       5     Output('example-graph', 'figure'),
#       6     [Input('dropdown', 'value')]
#       7 )
#       8 def update_graph(selected_value):
#       9     # Update plot based on selected value
#      10     fig = px.scatter(df, x='x', y='y', color='category')
#      11     return fig
#
# NameError: name 'app' is not defined

# %% [markdown]
# ---
#
# ## 1️⃣2️⃣.4️⃣ **Plotly Figures in Dash**
#
# - 📊 **Definition**:
#   **Plotly figures** can be seamlessly integrated into **Dash apps** using the `dcc.Graph` component. This allows Dash users to embed **interactive Plotly plots** within the app layout. By leveraging Plotly’s extensive charting capabilities, you can display a variety of **interactive visualizations**, such as line charts, bar charts, scatter plots, heatmaps, and more, directly within a Dash web application.
#
# ---
#
# ### 🔧 **Key Components**
#
# - **`dcc.Graph`**:
#   The **Dash Core Component** used to display Plotly figures. It can render a wide range of visualizations, such as 2D and 3D charts, and support dynamic updates via callbacks.
#
#   ```python
#   import dash_core_components as dcc
#
#   dcc.Graph(figure=plotly_figure)
#   ```
#
# - **`figure`**:
#   This attribute holds the **Plotly figure** object, which contains all the data and layout details for the chart. The figure is created using Plotly’s `go.Figure()` or `plotly.express` functions.
#
# ---
#
# ### 🔧 **Example: Integrating Plotly Figure in Dash**
#
# Here’s a simple example of embedding a Plotly figure into a Dash app:
#
# ```python
# import dash
# from dash import dcc, html
# import plotly.express as px
#
# # Initialize Dash app
# app = dash.Dash(__name__)
#
# # Sample Plotly figure
# fig = px.scatter(x=[1, 2, 3], y=[4, 5, 6], title="Scatter Plot Example")
#
# # Layout of Dash app
# app.layout = html.Div([
#     html.H1("Dash with Plotly Example"),
#     dcc.Graph(figure=fig)  # Plotly figure embedded in Dash app
# ])
#
# # Run app
# if __name__ == '__main__':
#     app.run_server(debug=True)
# ```
#
# In this example:
# - The **scatter plot** created with Plotly Express (`px.scatter()`) is passed into the `dcc.Graph` component's `figure` attribute.
# - The app displays the interactive **scatter plot** directly within the layout.
#
# ---
#
# ### 🔄 **Dynamic Plot Updates**
# - Plotly figures in Dash can also be dynamically updated using **callbacks**. For instance, a callback can modify the figure’s data or layout properties based on user input, such as a dropdown selection or slider movement.
#
# > ✅ **Tip**: Using `dcc.Graph` allows for the integration of **dynamic Plotly charts** into Dash apps, combining the flexibility of Plotly’s interactive charts with Dash’s powerful web application framework.
#
# ---

# %% [markdown]
# ---
#
# ## 1️⃣3️⃣ **Exporting and Sharing Plots**
#
# - 📤 **Definition**:
#   Plotly offers multiple ways to **export** and **share** plots. You can save your interactive visualizations as **static images**, export them as **HTML files**, or share them directly through various online platforms. These options provide flexibility for both sharing plots in reports and integrating them into external applications or websites.
#
# ---
#
# ## 1️⃣3️⃣.1️⃣ **Exporting to Static Images**
#
# - 🖼️ **Static Image Formats**:
#   Plotly supports exporting plots as static images in popular formats like **PNG**, **JPEG**, **SVG**, and **PDF**. This is particularly useful when you need to embed a plot into non-interactive environments such as printed reports or presentations.
#
# - 🔧 **Method**:
#   To export a Plotly figure to a static image, use the `plotly.io.write_image()` function. You will need to have the **kaleido** package installed for this functionality.
#
#   **Installation**:
#   ```bash
#   pip install kaleido
#   ```
#
#   **Example**:
#
#   ```python
#   import plotly.graph_objects as go
#   import plotly.io as pio
#
#   # Create a Plotly figure
#   fig = go.Figure(data=go.Scatter(x=[1, 2, 3], y=[4, 5, 6], mode='markers'))
#
#   # Export the figure as a static PNG image
#   pio.write_image(fig, 'plot.png')
#
#   # Export as SVG
#   pio.write_image(fig, 'plot.svg')
#   ```
#
#   In this example:
#   - The **scatter plot** is created and then exported as both a **PNG** and **SVG** file using `write_image()`.
#
# - 📄 **Other Static Formats**:
#   You can also export the figure to a **PDF** file for high-quality printing or sharing via email.
#
#   ```python
#   pio.write_image(fig, 'plot.pdf')
#   ```
#
# > ✅ **Tip**: Use static image exports when you need a **non-interactive version** of your plot for reports, publications, or presentations.
#
# ---

# %% [markdown]
# **Exporting to Interactive HTML Files**

# %%
fig.write_html('my_plot.html')

# %% [markdown]
# ---
#
# ## 1️⃣3️⃣.2️⃣ **Plotly Cloud**
#
# - ☁️ **Definition**:
#   **Plotly Cloud** allows users to **upload and share interactive plots** online. By signing into a Plotly account, users can save their plots on the cloud, making them accessible from anywhere and shareable with others. This is particularly useful for sharing interactive visualizations with collaborators or the public without requiring complex web hosting setups.
#
# - 🔧 **How to Use Plotly Cloud**:
#   1. **Sign In**:
#      Create a free account on the Plotly website or log in to your existing account.
#   2. **Upload Plot**:
#      Use `plotly.graph_objects` or `plotly.express` to create a plot and then upload it to Plotly Cloud.
#   3. **Share Link**:
#      Once uploaded, Plotly provides a **shareable link** to the plot. This link can be shared with others or embedded in web applications.
#
#   **Example**:
#
#   ```python
#   import plotly.graph_objects as go
#   import plotly.plotly as py
#
#   # Create a Plotly figure
#   fig = go.Figure(data=go.Scatter(x=[1, 2, 3], y=[4, 5, 6], mode='markers'))
#
#   # Upload the plot to Plotly Cloud
#   py.plot(fig, filename='interactive-plot')
#   ```
#
#   In this example:
#   - The plot is uploaded to Plotly Cloud and assigned the name **'interactive-plot'**.
#   - Once uploaded, Plotly will provide a URL to the plot that can be shared or embedded.
#
# > ✅ **Tip**: Plotly Cloud is ideal for sharing **interactive plots** without requiring a web server or complex setup.
#
# ---
#
# ## 1️⃣3️⃣.3️⃣ **Embedding in Web Pages**
#
# - 🌐 **Definition**:
#   Plotly plots can be embedded into **web pages** using **HTML** or **JavaScript**. This allows you to integrate interactive visualizations directly into your websites or blogs. Whether using a Plotly Cloud link or local plot, embedding gives users access to your interactive charts directly on the page.
#
# - 🔧 **Embedding with HTML**:
#   If you have a Plotly figure or a Plotly Cloud plot, you can embed it using an **iframe** tag in your HTML code. For example:
#
#   ```html
#   <iframe width="100%" height="600" src="https://plotly.com/~username/plot-id" frameborder="0"></iframe>
#   ```
#
#   - Replace `username` with your Plotly username and `plot-id` with the ID of your specific plot.
#
# - 🔧 **Embedding with JavaScript**:
#   For more control, you can embed Plotly plots using JavaScript. You can use the `Plotly.newPlot()` function to render the plot dynamically on your web page.
#
#   ```html
#   <div id="plotly-plot"></div>
#   <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#   <script>
#     var trace1 = {
#       x: [1, 2, 3],
#       y: [4, 5, 6],
#       mode: 'markers',
#     };
#     var layout = { title: 'Scatter Plot Example' };
#     var data = [trace1];
#     Plotly.newPlot('plotly-plot', data, layout);
#   </script>
#   ```
#
#   In this example:
#   - The plot is created and rendered directly in a `<div>` element with the ID `plotly-plot`.
#   - The `Plotly.newPlot()` function is used to display the plot.
#
# > ✅ **Tip**: Embedding Plotly plots using **iframe** is a quick and easy way to share interactive plots, while JavaScript embedding offers more customization options.
#
# ---

# %%
# <div id="myPlot"></div>
# <script>
#     Plotly.newPlot('myPlot', data, layout);
# </script>

# %% [markdown]
# ---
#
# ## 1️⃣4️⃣ **Plotly Graph Objects**
#
# - 🧩 **Definition**:
#   **Plotly Graph Objects** offer a more granular level of control for creating and customizing plots. These objects provide the ability to define data, layout, and style, allowing for detailed and fine-tuned visualizations. With Graph Objects, users can manipulate each part of the plot, such as traces (data), layout (appearance), and annotations, offering full flexibility for creating complex charts.
#
# ---
#
# ## 1️⃣4️⃣.1️⃣ **Figure Object**
#
# - 🖼️ **Definition**:
#   The **Figure object** in Plotly is the container for the entire plot. It holds both the **data** (such as traces) and the **layout** (such as titles, axes, and colors). It is the core object used when working with Plotly’s Graph Objects, combining all plot elements into a unified structure.
#
# - 🔧 **Structure of the Figure Object**:
#   - **`data`**: Contains the plot data (traces), where each trace represents a specific type of plot (e.g., scatter, bar, line).
#   - **`layout`**: Contains the configuration of the plot's layout, such as axis labels, title, and legend.
#   - **`frames`**: Defines animations and transitions in the plot (optional for dynamic plots).
#
# - 📝 **Creating a Figure Object**:
#   The `go.Figure()` constructor is used to create a figure object. You can define **data** and **layout** directly when initializing it.
#
#   **Example**:
#
#   ```python
#   import plotly.graph_objects as go
#
#   # Create data for the plot (trace)
#   trace = go.Scatter(x=[1, 2, 3], y=[4, 5, 6], mode='lines', name='Line Chart')
#
#   # Define the layout
#   layout = go.Layout(title='Basic Line Chart', xaxis=dict(title='X Axis'), yaxis=dict(title='Y Axis'))
#
#   # Create a Figure object
#   fig = go.Figure(data=[trace], layout=layout)
#
#   # Show the figure
#   fig.show()
#   ```
#
#   In this example:
#   - A **scatter plot** trace is created using `go.Scatter()`.
#   - The **layout** object is defined with a title and axis labels.
#   - The **Figure object** is created by passing both the trace and layout to `go.Figure()`.
#
# ---
#
# ### 🔧 **Key Attributes of the Figure Object**:
#
# | Attribute      | Description                                                              |
# |----------------|--------------------------------------------------------------------------|
# | 📊 `data`      | A list of plot traces (e.g., `go.Scatter`, `go.Bar`, etc.).              |
# | 🎨 `layout`    | Configurations for the layout (e.g., title, axes, legend, background).  |
# | 🎞️ `frames`    | Defines frames for creating animations (optional for dynamic plots).    |
#
# > ✅ **Tip**: The **Figure object** acts as the central control point for creating complex visualizations in Plotly, where you can dynamically adjust the data and layout.
#
# ---

# %%
fig = go.Figure(data=go.Scatter(x=x, y=y))
fig.update_layout(title='Figure Object Example')
fig.show()

# %% [markdown]
# ---
#
# ## 1️⃣4️⃣.2️⃣ **Trace Objects**
#
# - 📊 **Definition**:
#   **Trace objects** represent individual data visualizations within a Plotly plot. Each trace corresponds to a specific plot type (e.g., scatter, bar, line, pie) and contains the data that will be displayed on the plot. Traces allow you to add multiple layers of data to a single plot, such as multiple lines in a line chart or different categories in a bar chart.
#
# - 🔧 **Creating Trace Objects**:
#   To create a trace, you use specific trace constructors from `plotly.graph_objects`, such as `go.Scatter()` for scatter plots, `go.Bar()` for bar charts, etc.
#
#   **Example**:
#
#   ```python
#   import plotly.graph_objects as go
#
#   # Create a trace for a scatter plot
#   trace = go.Scatter(x=[1, 2, 3], y=[4, 5, 6], mode='markers', name='Data Points')
#
#   # Create a figure using the trace
#   fig = go.Figure(data=[trace])
#
#   # Show the plot
#   fig.show()
#   ```
#
#   In this example:
#   - A **scatter trace** is created using `go.Scatter()`, which contains the data points and visual style (markers).
#   - The **trace** is passed to the `data` parameter when creating the **Figure** object.
#
# ---
#
# ## 1️⃣4️⃣.3️⃣ **Layout Object**
#
# - 🖌️ **Definition**:
#   The **Layout object** controls the overall **appearance** of the plot, including aspects such as titles, axes, legends, gridlines, and colors. It defines the structure and style of the plot, ensuring that the visual presentation aligns with the user's requirements.
#
# - 🔧 **Common Layout Attributes**:
#   - **`title`**: Set the plot's main title.
#   - **`xaxis`** and **`yaxis`**: Configure the axes, including titles, range, and tick marks.
#   - **`legend`**: Customize the plot's legend (position, font, etc.).
#   - **`margin`**: Adjust the plot’s margins.
#
#   **Example**:
#
#   ```python
#   layout = go.Layout(
#       title='Customized Plot',
#       xaxis=dict(title='X Axis'),
#       yaxis=dict(title='Y Axis'),
#       margin=dict(l=50, r=50, t=50, b=50)
#   )
#   ```
#
#   This layout:
#   - Sets the **title** for the plot.
#   - Specifies titles for both the **x** and **y** axes.
#   - Adjusts the **margins** around the plot.
#
# ---
#
# ## 1️⃣4️⃣.4️⃣ **Customizing Traces**
#
# - 🎨 **Definition**:
#   Traces in Plotly can be highly customized by modifying various attributes. These attributes control the appearance and behavior of the data elements in the plot, such as markers, lines, text, and hover text.
#
# - 🔧 **Common Customizations for Traces**:
#   - **`marker`**: Customize the appearance of data points in scatter plots (e.g., color, size, symbol).
#   - **`line`**: Customize the appearance of lines (e.g., color, width, dash style).
#   - **`text`**: Add text labels for data points.
#   - **`hovertext`**: Provide additional information that appears when hovering over data points.
#
#   **Example**:
#
#   ```python
#   trace = go.Scatter(
#       x=[1, 2, 3],
#       y=[4, 5, 6],
#       mode='markers+lines',
#       name='Data Points',
#       marker=dict(color='red', size=12, symbol='circle'),
#       line=dict(color='blue', width=3, dash='dash'),
#       text=['Point 1', 'Point 2', 'Point 3'],
#       hovertext=['This is Point 1', 'This is Point 2', 'This is Point 3']
#   )
#   ```
#
#   In this example:
#   - The **`marker`** is customized to display **red circles** with a size of **12**.
#   - The **`line`** is customized with a **blue dashed line** of width **3**.
#   - The **`text`** and **`hovertext`** are used to display custom labels and hover information.
#
# > ✅ **Tip**: Customizing traces is a powerful way to enhance the visual appeal and interactivity of your plots, making them more informative and engaging.
#
# ---

# %%
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', marker=dict(size=10, color='blue')))
fig.show()

# %% [markdown]
# ---
#
# ## 1️⃣4️⃣.5️⃣ **Creating Complex Plots**
#
# - 🧩 **Definition**:
#   **Complex plots** in Plotly are created by combining multiple **traces** and **layout elements** to visualize more intricate datasets. These plots allow you to integrate multiple chart types (e.g., scatter, bar, line, pie) in a single figure, offering more detailed insights and interactivity. By layering different traces and customizing layout options, you can create advanced visualizations suited to various data exploration tasks.
#
# ---
#
# ### 🔧 **Steps for Creating Complex Plots**:
#
# 1. **Combine Multiple Traces**:
#    A complex plot often includes multiple traces that represent different kinds of data. For example, you might use a scatter plot for one dataset and a line chart for another within the same figure.
#
# 2. **Customize the Layout**:
#    You can add custom layout elements such as titles, axis labels, and legends to structure the plot. Additionally, adjusting margins, grid lines, and annotations can help improve readability.
#
# 3. **Use Subplots**:
#    Plotly supports subplot creation, where multiple plots can be arranged within a single figure. Each subplot can display different data, which is useful for comparing datasets visually.
#
# 4. **Enhance with Interactive Features**:
#    Add interactivity (e.g., hover text, clickable elements, sliders) to enable users to explore the data in greater depth.
#
# ---
#
# ### 🖌️ **Example of a Complex Plot**:
#
# In this example, we'll combine multiple traces (scatter and line) and add custom layout elements like titles and axis labels.
#
# ```python
# import plotly.graph_objects as go
#
# # Create a scatter trace
# scatter_trace = go.Scatter(
#     x=[1, 2, 3, 4],
#     y=[10, 11, 12, 13],
#     mode='markers',
#     name='Scatter Points'
# )
#
# # Create a line trace
# line_trace = go.Scatter(
#     x=[1, 2, 3, 4],
#     y=[5, 6, 7, 8],
#     mode='lines',
#     name='Line Data',
#     line=dict(color='blue', width=2)
# )
#
# # Create the layout for the plot
# layout = go.Layout(
#     title='Complex Plot Example',
#     xaxis=dict(title='X Axis Label'),
#     yaxis=dict(title='Y Axis Label'),
#     showlegend=True
# )
#
# # Create the figure with both traces
# fig = go.Figure(data=[scatter_trace, line_trace], layout=layout)
#
# # Show the figure
# fig.show()
# ```
#
# In this example:
# - A **scatter trace** and a **line trace** are combined into a single plot.
# - The **layout** is customized to include a title, axis labels, and a legend.
# - The **scatter trace** displays data points, and the **line trace** visualizes a trend.
#
# ---
#
# ### 🔧 **Additional Tips for Complex Plots**:
# - **Subplots**: Use `plotly.subplots.make_subplots()` to arrange multiple charts within the same figure.
# - **Shared Axes**: When combining multiple plots, you can choose to share axes between them (e.g., multiple line charts on the same x-axis).
# - **Annotations and Shapes**: Add extra elements like annotations and shapes to emphasize key points or trends in the data.
#
# ---

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Line Plot'))
fig.add_trace(go.Bar(x=x, y=y, name='Bar Plot'))
fig.show()

# %% [markdown]
# ---
#
# ## 1️⃣5️⃣ **Advanced Topics**
#
# - 📊 **Overview**:
#   Advanced topics in Plotly offer powerful tools and techniques for creating more complex visualizations, optimizing performance, and extending functionality. These topics include 3D plots, dynamic data updates, performance improvements, and custom components.
#
# ---
#
# ### 1️⃣5️⃣.1️⃣ **3D Volume Plots**
#
# - 🌐 **Definition**:
#   **3D volume plots** are used to visualize volumetric data in three-dimensional space. These plots are particularly useful for scientific data, medical imaging, and physics, where data points span a 3D grid.
#
# - 🔧 **Creating 3D Volume Plots**:
#   To create a 3D volume plot in Plotly, you can use the `plotly.graph_objects.Volume` object. This object visualizes data as a 3D volume where colors represent intensity.
#
#   **Example**:
#
#   ```python
#   import plotly.graph_objects as go
#   import numpy as np
#
#   # Create sample 3D volume data
#   x, y, z = np.mgrid[:10, :10, :10]
#   values = np.random.rand(10, 10, 10)
#
#   # Create a 3D volume plot
#   fig = go.Figure(data=go.Volume(
#       x=x.flatten(), y=y.flatten(), z=z.flatten(), value=values.flatten(),
#       opacity=0.1, surface_count=17
#   ))
#
#   # Show the plot
#   fig.show()
#   ```
#
#   In this example:
#   - **3D volume data** is generated using `numpy`.
#   - The **`go.Volume()`** object is used to create the 3D volume plot.
#
# ---
#
# ### 1️⃣5️⃣.2️⃣ **Data Updates**
#
# - 🔄 **Definition**:
#   **Data updates** allow you to modify the data in an existing plot dynamically. This is useful for real-time data visualization and dashboards.
#
# - 🔧 **Techniques for Data Updates**:
#   - **`fig.update_traces()`**: Used to update the data or styling of a trace.
#   - **`fig.extend_data()`**: Adds data points to an existing plot without re-drawing it, useful for streaming data.
#
#   **Example** (using `update_traces`):
#
#   ```python
#   # Create initial plot
#   fig = go.Figure(data=[go.Scatter(x=[1, 2, 3], y=[4, 5, 6])])
#
#   # Update trace data
#   fig.update_traces(x=[2, 3, 4], y=[5, 6, 7])
#
#   # Show updated plot
#   fig.show()
#   ```
#
# ---
#
# ### 1️⃣5️⃣.3️⃣ **Performance Optimization**
#
# - 🚀 **Definition**:
#   Performance optimization techniques are essential when working with large datasets or complex visualizations. These techniques can improve rendering speed and responsiveness.
#
# - 🔧 **Optimization Techniques**:
#   - **Offline Rendering**: Reduces rendering time by generating static images or exporting to formats like PNG, JPEG, or SVG, which are quicker to render than dynamic plots.
#   - **WebGL Acceleration**: Plotly automatically uses **WebGL** for 3D plots or high-density scatter plots, enhancing performance by offloading rendering to the GPU.
#
#   **Example** (Offline Rendering):
#
#   ```python
#   import plotly.io as pio
#   pio.write_image(fig, 'plot.png')  # Save plot as static PNG
#   ```
#
#   **WebGL for Scatter Plot**:
#
#   ```python
#   fig = go.Figure(data=go.Scatter3d(
#       x=x_data, y=y_data, z=z_data, mode='markers', marker=dict(size=3)
#   ))
#   fig.update_layout(scene=dict(xaxis=dict(showbackground=False)))
#   fig.show()
#   ```
#
# ---
#
# ### 1️⃣5️⃣.4️⃣ **Custom Components**
#
# - 🛠️ **Definition**:
#   **Custom components** in Plotly allow for enhanced interactivity and functionality by integrating JavaScript code. These components can extend Plotly’s capabilities beyond what is offered by default.
#
# - 🔧 **Creating Custom Components**:
#   Custom components can be built using **Dash** (Plotly’s web framework) and JavaScript to enable functionalities like interactive sliders, dropdowns, or even custom widgets that interact with the data visualizations.
#
#   **Example**:
#   - Use **Dash** to create custom sliders that dynamically update a plot's data or appearance based on user input.
#
# ---
