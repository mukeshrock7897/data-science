# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.cluster.vq import kmeans, vq

# ================================================================
# 1. Hierarchical Clustering (linkage, dendrogram, fcluster)
# ================================================================
print("\n1. Hierarchical Clustering:")

# Sample data (replace with your data)
X = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# Perform hierarchical clustering
Z = linkage(X, method='ward') # 'ward', 'single', 'complete', 'average'

# Plot dendrogram
plt.figure(figsize=(10, 7))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# Get cluster assignments
clusters = fcluster(Z, t=3, criterion='distance') # t is the threshold, criterion is how to use t

print(f"Cluster assignments: {clusters}")

print("\nConclusion (linkage, dendrogram, fcluster):")
print("linkage performs hierarchical clustering, dendrogram visualizes the clustering hierarchy, and fcluster assigns data points to clusters based on a distance threshold.  Ward's method minimizes the variance within each cluster.")

# Use Case: Exploratory data analysis, finding hierarchical relationships in data.


# ================================================================
# 2. K-Means Vector Quantization (kmeans, vq)
# ================================================================
print("\n2. K-Means Vector Quantization:")

# Sample data (replace with your data)
X = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# Perform k-means clustering
k = 2  # Number of clusters - Define k *before* calling kmeans
centroids, _ = kmeans(X, k)  # k is passed as a positional argument

# Assign data points to clusters
cluster_assignments, _ = vq(X, centroids)

print(f"Cluster centroids: \n{centroids}")
print(f"Cluster assignments: {cluster_assignments}")

plt.scatter(X[:, 0], X[:, 1], c=cluster_assignments)  # Color points by cluster
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=200, c='red', label='Centroids')  # Mark centroids
plt.legend()
plt.title('K-Means Clustering')
plt.show()

print("\nConclusion (kmeans, vq):")
print("kmeans performs k-means clustering to find cluster centers (centroids), and vq assigns data points to the nearest centroid. K-means aims to minimize the within-cluster variance.")

# Use Case: Data compression, image segmentation, customer segmentation.
# Out:
# 1. Hierarchical Clustering:
# Cluster assignments: [1 1 2 2 1 3]
#
# Conclusion (linkage, dendrogram, fcluster):
# linkage performs hierarchical clustering, dendrogram visualizes the clustering hierarchy, and fcluster assigns data points to clusters based on a distance threshold.  Ward's method minimizes the variance within each cluster.
#
# 2. K-Means Vector Quantization:
# Cluster centroids:
# [[7.33333333 9.        ]
#  [1.16666667 1.46666667]]
# Cluster assignments: [1 1 0 0 1 0]
# Conclusion (kmeans, vq):
# kmeans performs k-means clustering to find cluster centers (centroids), and vq assigns data points to the nearest centroid. K-means aims to minimize the within-cluster variance.
